# %%
from shape import *   # Imports only Circle and Rectangle

c = Circle (5)
r = Rectangle(4, 6)

print("Circle Area:", c.area())
print("Rectangle Area:", r.area())
# Out:
# Circle Area: 78.53981633974483
# Rectangle Area: 24
