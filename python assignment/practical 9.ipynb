# %%
from circles import Point, Circle

# Create Point object
center = Point(2, 3)

# Create Circle object
cir = Circle(center, 4)

# Display result
print(cir.display())
# Out:
# Center: (2, 3)
# Radius: 4
# Area: 50.27
# Circumference: 25.13
